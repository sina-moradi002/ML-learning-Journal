# %% [markdown]
#  ## **Session2** - Random Variables and Probability Theory Fundumentals
# متغیری است که مقدار آن بسته به یک احتمال یا شانس بستگی دارد. مانند پرتاب یک تاس. درواقع در مورد مقدار آن عدم قطعیت وجود دارد.
#
# دو نوع است:
# 1. گسسته: مانند تعداد یک چیز
# 2. پیوسته: مانند زمان مورد نیاز برای انجام یک کار

# %% [markdown]
# ### Discrete Random Variables
# دارای مقادیر قابل شمارش و مجزا است.
#
# ویژگی ها:
# - مجموعه قابل شمارش ازز احتمالات ممکن
# - هر مقدار یک احتمال نا منفی دارد
# - مجموع تمام احتمالات برابر 1 است.
#
# #### Probability Mass Function (PMF)
# The Probability Mass Function (PMF) of a discrete random variable X is a function that gives the probability that X takes on exactly the value x:$$ px(x) = P(X=x) $$
#
# #### Properties
# 1. px(x) >= 0
# 2. sum = 1

# %% [markdown]
# ### Continuous Random Variable
# مقادیر آن غیر قابل شمارش و پیوسته اند.
#
# ویژگی ها:
# - میتواند هر مقداری داخل یک بازه را بپذیرد
# - احتمال هر مقدار دقیق در آن صفر است.
# - احتمالات روی بازه ها سنجیده می شود.
#
# #### Probability Density Function (PDF)
# A Probability Density Function (PDF) is used to describe the probability distribution of a continuous random variable.
#
# **Definition:** For a continuous random variable X, the PDF $$ f_X(x) $$ is a function such that the probability of X falling in an interval [a, b] is given by the integral of $$ f_X(x) $$ over that interval:
# $$ P(a \leq X \leq b) = \int_a^b f_X(x) dx $$

# %% [markdown]
# ### Cumulative Distribution Function (CDF)
# تابع توزیع تجمعی به زبان ساده یعنی: «احتمال اینکه یک متغیر تصادفی، مقداری
# کوچک‌تر یا مساوی با یک عدد مشخص بگیرد.»
#
# نمودار آن همیشه اکیدا صعودی است. از صفر شروع می شود و کم کم به یک می رسد.
